# %% [markdown]
# <a href="https://colab.research.google.com/github/JhonnyLimachi/Rstudio/blob/main/1_Boxplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
datos= c(1,2,3,4,5,8,12,16,19)

# %%
datos
# Out:
# [1]  1  2  3  4  5  8 12 16 19

# %%
boxplot(datos)
# Out:
# plot without title

# %%
boxplot (datos, main="nutricion")
# Out:
# Plot with title “nutricion”

# %%
hist(datos)
# Out:
# Plot with title “Histogram of datos”

# %%
hist(datos, main = "Histograma de datos", xlab = "porcentajes", ylab = "recuento", col = "red")
# Out:
# Plot with title “Histograma de datos”

# %%
table(datos)
# Out:
# datos
#  1  2  3  4  5  8 12 16 19
#  1  1  1  1  1  1  1  1  1

# %%
log(10)
# Out:
# [1] 2.302585

# %%
exp(1)
# Out:
# [1] 2.718282

# %%
p1= choose(10,3)*((0.25)^3)+((0.75)^7)

# %%
dbinom(3,10,0.25)
# Out:
# [1] 0.2502823

# %%
a=3
b=5
c=9

d=a+b
d
print(d)
# Out:
# [1] 8
# [1] 8

# %%
r= a+b

# %%
v= c(1,2,3,4,5)

# %%
u= c(v,20)
print(u)
# Out:
# [1]  1  2  3  4  5 20
